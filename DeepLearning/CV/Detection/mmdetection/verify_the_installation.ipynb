# %%
from mmdet.apis import init_detector, inference_detector

config_file = 'checkpoints/yolov3_mobilenetv2_320_300e_coco.py'
checkpoint_file = 'checkpoints/yolov3_mobilenetv2_320_300e_coco_20210719_215349-d18dff72.pth'
model = init_detector(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'
img = 'mmdetection/demo/demo.jpg'
result = inference_detector(model, img)
model.show_result(img, result, show=True)
model.show_result(img, result, out_file='result.jpg')
# Out:
# /home/yuki/.pyenv/versions/3.10.7/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# load checkpoint from local path: checkpoints/yolov3_mobilenetv2_320_300e_coco_20210719_215349-d18dff72.pth
